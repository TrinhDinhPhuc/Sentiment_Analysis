# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import our access keys:
from credentials import * # This will allow us to use the keys as variables

# %%
# API's setup:
def twitter_setup():
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="realDonaldTrump", count=300)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
# print("5 recent tweets:\n")
# for tweet in tweets[:1]:
#     print(tweet.created_at,"\n",tweet.contributors,"\n",tweet.retweets,"\n",tweet.author)
print(tweets[0].created_at,"\n\n\n\n\n",tweets[0].contributors,"\n\n\n\n\n",tweets[0].retweets,"\n\n\n\n\n",tweets[0].author)
# Out:
# Number of tweets extracted: 200.
#
# 2018-02-22 01:40:33
#
#
#
#
#  None
#
#
#
#
# ...

# %%
data =  pd.DataFrame(data=[tweet.text for tweet in tweets],columns=["Tweet"])

# %%
data.head()
# Out:
#                                                Tweet
# 0  I will always remember the time I spent today ...
# 1  .@FLOTUS Melania and I join millions of people...
# 2  Yesterday, it was my great honor to recognize ...
# 3  Question: If all of the Russian meddling took ...
# 4  The GREAT Billy Graham is dead. There was nobo...

# %%
data['create_at']=np.array([tweet.created_at for tweet in tweets])
data['author']=np.array([tweet.author for tweet in tweets])
data['contributors']=np.array([tweet.contributors for tweet in tweets])
data['retweet']=np.array([tweet.retweet for tweet in tweets])
data['retweets']=np.array([tweet.retweets for tweet in tweets])
data['place']=np.array([tweet.place for tweet in tweets])
data['user']=np.array([tweet.user for tweet in tweets])
data['retweeted']=np.array([tweet.retweeted for tweet in tweets])

# %%
data
# Out:
#                                                  Tweet           create_at  \
# 0    I will always remember the time I spent today ... 2018-02-22 01:40:33
# 1    .@FLOTUS Melania and I join millions of people... 2018-02-21 21:12:45
# 2    Yesterday, it was my great honor to recognize ... 2018-02-21 18:20:25
# 3    Question: If all of the Russian meddling took ... 2018-02-21 14:40:21
# 4    The GREAT Billy Graham is dead. There was nobo... 2018-02-21 14:22:07
# 5    @CNN @MSNBC Whether we are Republican or Democ... 2018-02-21 01:18:36
# 6          So true, thank you! https://t.co/9TTXlfokYz 2018-02-21 01:14:19
# 7    Bad ratings @CNN &amp; @MSNBC got scammed when... 2018-02-21 01:08:00
# 8    Main Street is BOOMING thanks to our incredibl... 2018-02-20 17:49:07
# 9    ....cameras running. Another False Accusation.... 2018-02-20 15:29:07
# 10   A woman I don’t know and, to the best of my kn... 2018-02-20 15:16:06
# ...
