# %%
from twython import Twython

# %%
def twitter_oauth_login():
    global twitter
    API_KEY = '1H3NUrvWq1OGuQVh9420Spvld'
    API_SECRET = '3YmiaPqyiuN00TNlHCKSgLLqfvrFr088nKT7qaukrtZXmZrx9R'
    ACCESS_TOKEN = '3093984751-qiZz5wMFAAPpWOXWodRSDnxu3FvRIqk9StTRaYk'
    ACCESS_TOKEN_SECRET = '0unFm1rVo6IepwyfoeKz79qCehGPCx2N3dcDAhL7DkD0Q'
    twitter = Twython(API_KEY, API_SECRET,ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    return(twitter)

# %% [markdown]
# ### This command will fetch the last 20 status updates from your timeline as a 20-element list of Python dictionaries.

# %%
twitter=twitter_oauth_login()

# %% [markdown]
# ### This will bring up the impressive list of API calls that are now available to you.

# %%
print(dir(twitter))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_error_message', '_last_call', '_request', 'access_token', 'access_token_url', 'add_list_member', 'api_url', 'api_version', 'app_key', 'app_secret', 'authenticate_url', 'client', 'client_args', 'construct_api_url', 'create_block', 'create_favorite', 'create_friendship', 'create_list', 'create_list_members', 'create_mute', 'create_place', 'create_saved_search', 'cursor', 'delete_list', 'delete_list_member', 'delete_list_members', 'destroy_block', 'destroy_direct_message', 'destroy_favorite', 'destroy_friendship', 'destroy_mute', 'destroy_saved_search', 'destroy_status', 'encode', 'get', 'get_account_settings', 'get_application_rate_limit_sta
# ...

# %%
temp=twitter.get_user_timeline()

# %%
temp
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Nov 18 17:35:15 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 16242081,
#      'id_str': '16242081',
#      'indices': [0, 10],
#      'name': 'Ben Horowitz',
#      'screen_name': 'bhorowitz'},
#     {'id': 1362590071,
#      'id_str': '1362590071',
#      'indices': [11, 22],
#      'name': 'News Genius',
#      'screen_name': 'newsgenius'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 931938869800353792,
#   'id_str': '931938869800353792',
#   'in_reply_to_screen_name': 'bhorowitz',
#   'in_reply_to_status_id': 489075605669830657,
#   'in_reply_to_status_id_str': '489075605669830657',
#   'in_reply_to_user_id': 16242081,
#   'in_reply_to_user_id_str': '16242081',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
# ...

# %%
friends_ids = twitter.get_friends_ids(count=5000)
friends_ids = friends_ids['ids']
followers_ids = twitter.get_followers_ids(count=5000)
followers_ids = followers_ids['ids']

# %%
print(friends_ids)
# Out:
# [511591627, 2443058040, 105353526, 176758255, 961445378, 877807935493033984, 902926941413453824, 2928997261, 1485057799, 44196397, 2479063608, 278476392, 571202103, 456910776, 31031011, 221230182, 2578998615, 20963651, 18793486, 1584340213, 2452113829, 23327926, 17266725, 2890578630, 45167431, 787639118, 5768872, 3312757710, 16991114, 2470761883, 49383389, 11595422, 2547785035, 15379361, 318063815, 38398940, 894057794, 216939636, 765548, 104532838, 250103509, 17911125, 781325090122182656, 108912006, 17915334, 294455339, 268744869, 90420314, 16193578, 27260086, 14920785, 50393960, 268439864, 23375688, 813286, 18091904, 141052723]

# %%
def pull_users_profiles(ids):
    users = []
    for i in range(0, len(ids), 100):
        batch = ids[i:i + 100]
        users += twitter.lookup_user(user_id=batch)
        print(twitter.get_lastfunction_header('x-rate-limitremaining'))
    return (users)
friends_profiles = pull_users_profiles(friends_ids)
# Out:
# None

# %%
import json
def save_json(filename, data):
    with open(filename, 'wb') as outfile:
        json.dump(data, outfile)
def load_json(filename):
    with open(filename) as infile:
        data = json.load(infile)
    return data

# %%
fname = "test_friends_profiles.json"
save_json(fname, friends_profiles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-51bc21d0a151> in <module>()
#       1 fname = "test_friends_profiles.json"
# ----> 2 save_json(fname, friends_profiles)
#
# <ipython-input-28-4e918eca465a> in save_json(filename, data)
#       2 def save_json(filename, data):
#       3     with open(filename, 'wb') as outfile:
# ----> 4         json.dump(data, outfile)
#       5 def load_json(filename):
#       6     with open(filename) as infile:
#
# C:\Users\USER\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# TypeError: a bytes-like object is required, not 'str'
